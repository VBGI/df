# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy.stats as st
data = pd.read_excel('data.xlsx', header=1)

# %% [markdown]
# ## Внутривидовая изменчивость (df) по количественным признакам

# %%
data_num = data[['L1p1l','L1p2l','W1p1l','W1p2l','L2p3l','L2p4l','W2p3l','W2p4l', 'S2p3l','S2p4l','Lkd','Wkd','OtnWLkd','Dvsh','Dosh','Lp','Dpl','Lns','Wns','Lvs','Wvs'
]]
data_nonnum =  data[['Dp','Dvl','Dnl','Dc','Dvns','Dnns','Dvvs','Dnvs']]
num_null = data_num.isnull().sum(axis=1)
nonnum_null = data_nonnum.isnull().sum(axis=1)
sp_var = data['Sp']
pop_var = data['idCP']

# %%
data_num = data_num[num_null==0]
sp_var = sp_var[num_null==0]

# %% [markdown]
# ### Анализ изменчивости для каждого вида в отдельности

# %%
most_constant = []
most_variable = []
for sp in sp_var.unique():
    sel = data_num[sp_var==sp]
    cvars = sel.var(axis=0) / sel.mean(axis=0) * 100.0
    cvars.sort_values(inplace=True)
    print('Coefficient of variations for %s' % sp, 'Sample size: ', np.sum(sp_var==sp))
    print(cvars)
    print('Top 10 Most constant features:')
    print(cvars.index[:10].tolist(),'\n'*2)
    most_constant.append(cvars.index[:10].tolist())
    most_variable.append(cvars.index[-10:].tolist())
print('Most constant features as matrix:\n', np.matrix(most_constant),'\n' * 2)
print('Most variable features as matrix:\n', np.matrix(most_variable),'\n' * 2)
print('\n\nCommon constant features:', set.intersection(*map(lambda x: set(x), most_constant)))
print('\n\nCommon variable features:', set.intersection(*map(lambda x: set(x), most_variable)))
# Out:
# Coefficient of variations for Df Sample size:  383
# OtnWLkd     0.563678
# S2p4l       4.169237
# Wvs         5.141845
# S2p3l       5.422698
# Wns         9.047363
# Lvs         9.795145
# W2p4l      10.508721
# Wkd        10.540564
# W2p3l      10.636286
# W1p2l      11.314903
# W1p1l      11.349886
# Lns        11.454953
# Dpl        11.867544
# Dvsh       20.226930
# Dosh       26.068964
# L1p2l      28.918738
# L1p1l      29.346109
# L2p4l      30.178134
# L2p3l      30.511250
# Lkd        30.891143
# Lp         61.841022
# dtype: float64
# Top 10 Most constant features:
# ['OtnWLkd', 'S2p4l', 'Wvs', 'S2p3l', 'Wns', 'Lvs', 'W2p4l', 'Wkd', 'W2p3l', 'W1p2l']
#
#
# Coefficient of variations for Dp Sample size:  20
# OtnWLkd    0.190843
# Wvs        0.380625
# Lvs        1.499871
# S2p4l      1.594441
# S2p3l      1.642105
# Wns        2.485036
# Wkd        2.951147
# Dpl        3.187465
# W1p1l      3.458033
# W1p2l      3.616379
# Dvsh       4.360428
# Lns        4.371019
# Lkd        4.989844
# W2p3l      5.235260
# Dosh       5.883148
# L1p1l      6.316665
# W2p4l      6.472765
# L1p2l      6.701347
# L2p3l      7.892396
# L2p4l      9.304703
# Lp         9.375599
# dtype: float64
# Top 10 Most constant features:
# ['OtnWLkd', 'Wvs', 'Lvs', 'S2p4l', 'S2p3l', 'Wns', 'Wkd', 'Dpl', 'W1p1l', 'W1p2l']
#
#
# Coefficient of variations for Dd Sample size:  81
# OtnWLkd     0.560498
# S2p4l       3.010478
# S2p3l       3.100959
# Wns         3.355262
# Dpl         3.633680
# Wvs         4.006430
# W2p3l       6.300155
# Lvs         6.489093
# Wkd         6.886231
# W2p4l       7.053384
# Dvsh        7.644436
# W1p1l       7.718926
# W1p2l       8.533259
# Lns         8.950653
# Dosh       14.836992
# L2p3l      15.173883
# Lkd        16.227979
# L1p1l      16.745082
# L1p2l      17.397859
# L2p4l      17.478908
# Lp         23.950186
# dtype: float64
# Top 10 Most constant features:
# ['OtnWLkd', 'S2p4l', 'S2p3l', 'Wns', 'Dpl', 'Wvs', 'W2p3l', 'Lvs', 'Wkd', 'W2p4l']
#
#
# Coefficient of variations for Ddvfl Sample size:  21
# OtnWLkd     0.402423
# Wvs         2.310207
# S2p4l       2.328586
# Wns         2.334220
# Lvs         2.712932
# S2p3l       3.061497
# Lns         4.277386
# Dvsh        4.546907
# Wkd         5.357791
# Dpl         6.526764
# L1p1l       6.543022
# L1p2l       6.912272
# W2p4l       6.995875
# Dosh        7.749932
# W2p3l       7.991088
# L2p3l       8.421626
# Lkd        10.858539
# W1p1l      11.562102
# W1p2l      12.247848
# L2p4l      13.988722
# Lp         27.569630
# dtype: float64
# Top 10 Most constant features:
# ['OtnWLkd', 'Wvs', 'S2p4l', 'Wns', 'Lvs', 'S2p3l', 'Lns', 'Dvsh', 'Wkd', 'Dpl']
#
#
# Coefficient of variations for Dm Sample size:  64
# OtnWLkd     0.277763
# S2p3l       3.530978
# Wvs         3.687701
# S2p4l       4.579951
# Wns         6.249408
# W2p4l       7.628440
# W2p3l       7.870839
# Dvsh        8.611198
# Lns         8.889857
# Dpl         9.538796
# Lvs         9.563296
# Wkd        11.016835
# W1p1l      11.692786
# W1p2l      12.214887
# Dosh       16.825042
# L1p2l      17.255735
# L1p1l      18.712794
# Lkd        21.760330
# L2p3l      23.713010
# L2p4l      23.955154
# Lp         39.136126
# dtype: float64
# Top 10 Most constant features:
# ['OtnWLkd', 'S2p3l', 'Wvs', 'S2p4l', 'Wns', 'W2p4l', 'W2p3l', 'Dvsh', 'Lns', 'Dpl']
#
#
# Coefficient of variations for Dg Sample size:  21
# OtnWLkd     0.487264
# S2p3l       2.010000
# S2p4l       2.219231
# Wvs         2.787150
# Dvsh        3.838042
# Wns         4.064462
# Dpl         4.471258
# W2p4l       4.558659
# W2p3l       5.747943
# Wkd         6.017334
# W1p2l       7.265968
# Lns         7.297166
# W1p1l       7.636294
# L2p4l       9.295709
# L1p2l      10.612926
# L2p3l      10.712561
# Lvs        10.842252
# Dosh       11.089540
# L1p1l      11.158857
# Lkd        13.242396
# Lp         37.185045
# dtype: float64
# Top 10 Most constant features:
# ['OtnWLkd', 'S2p3l', 'S2p4l', 'Wvs', 'Dvsh', 'Wns', 'Dpl', 'W2p4l', 'W2p3l', 'Wkd']
#
#
# Most constant features as matrix:
#  [['OtnWLkd' 'S2p4l' 'Wvs' 'S2p3l' 'Wns' 'Lvs' 'W2p4l' 'Wkd' 'W2p3l' 'W1p2l']
#  ['OtnWLkd' 'Wvs' 'Lvs' 'S2p4l' 'S2p3l' 'Wns' 'Wkd' 'Dpl' 'W1p1l' 'W1p2l']
#  ['OtnWLkd' 'S2p4l' 'S2p3l' 'Wns' 'Dpl' 'Wvs' 'W2p3l' 'Lvs' 'Wkd' 'W2p4l']
#  ['OtnWLkd' 'Wvs' 'S2p4l' 'Wns' 'Lvs' 'S2p3l' 'Lns' 'Dvsh' 'Wkd' 'Dpl']
#  ['OtnWLkd' 'S2p3l' 'Wvs' 'S2p4l' 'Wns' 'W2p4l' 'W2p3l' 'Dvsh' 'Lns' 'Dpl']
#  ['OtnWLkd' 'S2p3l' 'S2p4l' 'Wvs' 'Dvsh' 'Wns' 'Dpl' 'W2p4l' 'W2p3l' 'Wkd']]
#
#
# Most variable features as matrix:
#  [['Lns' 'Dpl' 'Dvsh' 'Dosh' 'L1p2l' 'L1p1l' 'L2p4l' 'L2p3l' 'Lkd' 'Lp']
#  ['Lns' 'Lkd' 'W2p3l' 'Dosh' 'L1p1l' 'W2p4l' 'L1p2l' 'L2p3l' 'L2p4l' 'Lp']
#  ['W1p1l' 'W1p2l' 'Lns' 'Dosh' 'L2p3l' 'Lkd' 'L1p1l' 'L1p2l' 'L2p4l' 'Lp']
#  ['L1p2l' 'W2p4l' 'Dosh' 'W2p3l' 'L2p3l' 'Lkd' 'W1p1l' 'W1p2l' 'L2p4l' 'Lp']
#  ['Wkd' 'W1p1l' 'W1p2l' 'Dosh' 'L1p2l' 'L1p1l' 'Lkd' 'L2p3l' 'L2p4l' 'Lp']
#  ['Lns' 'W1p1l' 'L2p4l' 'L1p2l' 'L2p3l' 'Lvs' 'Dosh' 'L1p1l' 'Lkd' 'Lp']]
#
#
#
#
# Common constant features: {'Wns', 'S2p4l', 'Wvs', 'S2p3l', 'OtnWLkd'}
#
#
# Common variable features: {'Dosh', 'L1p2l', 'L2p3l', 'Lkd', 'Lp', 'L2p4l'}

# %% [markdown]
# Таким образом, виды имеют приблизительно одинаковые наборы как изменчивых, так и констанстантных признаков, среди всех количественных признаков. При этом общими констанстными признаками являются {'Wns', 'S2p4l', 'Wvs', 'S2p3l', 'OtnWLkd'}, а общими, наиболее вариабельными - {'Dosh', 'L1p2l', 'L2p3l', 'Lkd', 'Lp', 'L2p4l'}.ы
